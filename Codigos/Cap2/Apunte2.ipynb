# %%
a = [1,2,3,4]
b = a
b
# Out:
# [1, 2, 3, 4]

# %%
def append_element(list, element):
    list.append(element)

append_element(a, 5)

a
# Out:
# [1, 2, 3, 4, 5, 5]

# %%
a = 5
isinstance(a,int)
# Out:
# True

# %%
name = "Dana" 
getattr(name, "split")
# Out:
# <function str.split(sep=None, maxsplit=-1)>

# %%
def isiterable(obj):
    try:
        iter(obj)
        return True
    except TypeError: #not iterable
        return False
    
isiterable("a string")
# Out:
# True

# %%
a = [1,2,3]
b = a
c = list(a)
d = None
print(a is b)
print(a is c)
print(a is d)
print(d is None)
print(a is None)
# Out:
# True
# False
# False
# True
# False

# %%
a == c
# Out:
# True
